# %%
import pandas as pd
import numpy as np
import requests
import json
import wget

from zipfile import ZipFile

from ipywidgets import widgets
from ipywidgets import interact

# %%
path = 'C:/Users/sguil/OneDrive/investimentos2/mercado_financeiro/dados_cvm_b3/'

itr = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/'

dfp = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/'

# %%
arquivos_itr_zip = []
for ano in range(2011,2024):
    arquivos_itr_zip.append(f'itr_cia_aberta_{ano}.zip')
    
arquivos_itr_zip


arquivos_dfp_zip = []
for ano in range(2011,2024):
    arquivos_dfp_zip.append(f'dfp_cia_aberta_{ano}.zip')
    
arquivos_dfp_zip
# Out:
# ['dfp_cia_aberta_2011.zip',
#  'dfp_cia_aberta_2012.zip',
#  'dfp_cia_aberta_2013.zip',
#  'dfp_cia_aberta_2014.zip',
#  'dfp_cia_aberta_2015.zip',
#  'dfp_cia_aberta_2016.zip',
#  'dfp_cia_aberta_2017.zip',
#  'dfp_cia_aberta_2018.zip',
#  'dfp_cia_aberta_2019.zip',
#  'dfp_cia_aberta_2020.zip',
#  'dfp_cia_aberta_2021.zip',
#  'dfp_cia_aberta_2022.zip',
#  'dfp_cia_aberta_2023.zip']

# %%
for arquivo in arquivos_itr_zip:
     wget.download(itr + arquivo)

for arquivo in arquivos_dfp_zip:
     wget.download(dfp + arquivo)

# %%
for arquivo in arquivos_itr_zip:
     ZipFile(path + 'ITR/' + arquivo,'r').extractall(path + 'ITR/')


for arquivo in arquivos_dfp_zip:
     ZipFile(path + 'DFP/' + arquivo,'r').extractall(path + 'DFP/')

# %%
nomes = ['BPA_con','BPA_ind','BPP_con','BPP_ind','DFC_MD_con',
        'DFC_MD_ind','DFC_MI_con','DFC_MI_ind','DMPL_con',
        'DMPL_ind','DRE_con','DRE_ind','DVA_con','DVA_ind']

for nome in nomes:
    arquivo = pd.DataFrame()
    for ano in range(2011,2024):
        arquivo = pd.concat([arquivo, 
            pd.read_csv(path + f'ITR/itr_cia_aberta_{nome}_{ano}.csv',
                            sep = ';', decimal = ',', encoding = 'ISO-8859-1')])
    arquivo.to_csv(path + 'DADOS_CONSOLIDADOS/itr_' + nome + '.csv', index = False)
    
    
for nome in nomes:
    arquivo = pd.DataFrame()
    for ano in range(2011,2024):
        arquivo = pd.concat([arquivo, 
            pd.read_csv(path + f'DFP/dfp_cia_aberta_{nome}_{ano}.csv',
                            sep = ';', decimal = ',', encoding = 'ISO-8859-1')])
    arquivo.to_csv(path + 'DADOS_CONSOLIDADOS/dfp_' + nome + '.csv', index = False)

# %%
df = pd.read_csv(path + 'DADOS_CONSOLIDADOS/' + 'dfp_DRE_con' + '.csv')

# %%
df
# Out:
#                   CNPJ_CIA    DT_REFER  VERSAO               DENOM_CIA  \
# 0       00.000.000/0001-91  2011-12-31       4         BCO BRASIL S.A.
# 1       00.000.000/0001-91  2011-12-31       4         BCO BRASIL S.A.
# 2       00.000.000/0001-91  2011-12-31       4         BCO BRASIL S.A.
# 3       00.000.000/0001-91  2011-12-31       4         BCO BRASIL S.A.
# 4       00.000.000/0001-91  2011-12-31       4         BCO BRASIL S.A.
# ...                    ...         ...     ...                     ...
# 326788  71.476.527/0001-35  2023-03-31       1  CONSTRUTORA TENDA S.A.
# 326789  71.476.527/0001-35  2023-03-31       1  CONSTRUTORA TENDA S.A.
# 326790  71.476.527/0001-35  2023-03-31       1  CONSTRUTORA TENDA S.A.
# 326791  71.476.527/0001-35  2023-03-31       1  CONSTRUTORA TENDA S.A.
# 326792  71.476.527/0001-35  2023-03-31       1  CONSTRUTORA TENDA S.A.
#
#         CD_CVM                                   GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0         1023  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1         1023  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 2         1023  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 3         1023  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 4         1023  DF Consolidado - Demonstração do Resultado  REAL          MIL
# ...        ...                                         ...   ...          ...
# 326788   21148  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 326789   21148  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 326790   21148  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 326791   21148  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 326792   21148  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#        ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC    CD_CONTA  \
# 0        PENÚLTIMO   2010-01-01   2010-12-31        3.01
# 1           ÚLTIMO   2011-01-01   2011-12-31        3.01
# 2        PENÚLTIMO   2010-01-01   2010-12-31     3.01.01
# 3           ÚLTIMO   2011-01-01   2011-12-31     3.01.01
# 4        PENÚLTIMO   2010-01-01   2010-12-31        3.02
# ...            ...          ...          ...         ...
# 326788      ÚLTIMO   2023-01-01   2023-03-31  3.99.01.01
# 326789   PENÚLTIMO   2022-01-01   2022-12-31     3.99.02
# 326790      ÚLTIMO   2023-01-01   2023-03-31     3.99.02
# 326791   PENÚLTIMO   2022-01-01   2022-12-31  3.99.02.01
# 326792      ÚLTIMO   2023-01-01   2023-03-31  3.99.02.01
#
#                                     DS_CONTA      VL_CONTA ST_CONTA_FIXA
# 0       Receitas da Intermediação Financeira  8.514321e+07             S
# 1       Receitas da Intermediação Financeira  1.069198e+08             S
# 2                           Receita de Juros  8.514321e+07             S
# 3                           Receita de Juros  1.069198e+08             S
# 4       Despesas da Intermediação Financeira -5.077574e+07             S
# ...                                      ...           ...           ...
# 326788                                    ON -4.141000e-01             N
# 326789                Lucro Diluído por Ação  0.000000e+00             N
# 326790                Lucro Diluído por Ação  0.000000e+00             N
# 326791                                    ON -5.346200e+00             N
# 326792                                    ON -3.918000e-01             N
#
# [326793 rows x 15 columns]
